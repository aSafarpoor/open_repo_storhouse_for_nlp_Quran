# %% [markdown]
# <a href="https://colab.research.google.com/github/aSafarpoor/open_repo_storhouse_for_nlp_Quran/blob/main/reLabeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # read data and preprocessin

# %%
# !wget https://raw.githubusercontent.com/aSafarpoor/open_repo_storhouse_for_nlp_Quran/main/train.csv
# !wget https://raw.githubusercontent.com/aSafarpoor/open_repo_storhouse_for_nlp_Quran/main/eval.csv
# Out:
# --2022-01-05 10:58:55--  https://raw.githubusercontent.com/aSafarpoor/open_repo_storhouse_for_nlp_Quran/main/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170861 (167K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>] 166.86K  --.-KB/s    in 0.02s
#
# 2022-01-05 10:58:55 (10.4 MB/s) - ‘train.csv’ saved [170861/170861]
#
# --2022-01-05 10:58:55--  https://raw.githubusercontent.com/aSafarpoor/open_repo_storhouse_for_nlp_Quran/main/eval.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# ...

# %%
import pandas as pd

# %%
train = pd.read_csv("train.csv")
eval = pd.read_csv("eval.csv")

# %%
print(len(eval))
# Out:
# 200

# %%
for i in range(109,len(eval)):
    print('<',i,'>  ',eval.rate[i] , eval.comment[i] )
    x = int(input())
    eval.rate[i] = x
# Out:
# < 109 >   1.0 با توجه به این امکانات سخت افزاری نمی‌توان انتظار سرعت فوق‌العاده یا انجام وظایف پیچیده ای مانند اجرای روان بی عیب نقص چندین برنامه سنگین در کنار هم را از این گوشی داشت.
# 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# < 110 >   -1.0 بهترین مرغ بریونی که خوردم. فوق العاده خوشمزه و به اندازه کافی بریان. متشکرم
# 1
# < 111 >   1.0 لنز ZS6 خیلی لنز خوبی است به طوری که کمینه ی فاصله ی کانونی آن 26 میلی متر می باشد که در این حال میدان دید خیلی گسترده ای را می تواند در یک میدان دید پوشش دهد.
# 1
# < 112 >   1.0 به قیمتش واقعا میارزه. پیش خودم گفتم اصلا کار نمیده اما واسه توی کیف و شارژ اپل از پاور بانک واقعا مفید و عالیه
# 1
# ...

# %%
eval
# Out:
#      Unnamed: 0                                            comment  rate
# 0         61591                    کیفیت غذا و زمان رسیدن عالی بود   1.0
# 1         50299  در‌ حد ساندویچ یه نفره بود نه دونفره یا بمب. ک...  -1.0
# 2          2777  طعم پیتزای چهار فصل مثل همشه خیلی خوب بود اما ...   0.0
# 3          9126  مشخصات سخت افزاری مناسب در کنار سیستم عامل وین...   1.0
# 4          7544  مرغش سوخاری و خوشمزه بود، بسته بندی عالی، قیمت...   1.0
# ..          ...                                                ...   ...
# 195        3939  خود کتاب داستان جذابی نداشت و ترجمه جلال کار ر...  -1.0
# 196       44573  زرشک پلو به شدت شور بود. یعنی شور بودا …. فک ک...  -1.0
# 197        8871  دوربین دوربین 5 مگاپیکسلی iSight با لنز F2.4 و...   1.0
# 198        3837  من بالاخره اين گوشيو مي خرم قيمتشم برام مهم نيست.   0.0
# 199        6478  باید هنگام تمرکز ذهن خیلی دقیق بود چون در همون...   0.0
#
# [200 rows x 3 columns]

# %%
import pandas as pd
store = pd.HDFStore('eval_v1_store.h5')

store['df'] = eval  # save it
# store['df']  # load it
